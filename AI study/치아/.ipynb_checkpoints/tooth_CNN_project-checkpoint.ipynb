# %% [markdown]
# <a href="https://colab.research.google.com/github/KyungRyeolBaek/study/blob/main/AI%20study/%EC%B9%98%EC%95%84/tooth_CNN_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tooth_CNN

# %% [markdown]
# # 모듈 import

# %%
import numpy as np
import pandas as pd
import keras, os, math
import matplotlib.pyplot as plt
import tensorflow as tf
from tqdm import notebook
from tensorflow.keras.models import load_model
from tensorflow.python.client import device_lib 
from tensorflow.keras import datasets, layers, models

# %%
# tqdm 모듈이 없을시 이부분 실행
# !pip install tqdm
# !pip install tqdm --upgrade

# %% [markdown]
# # GPU 작동 방법

# %%
# Ture가 나와야 GPU가 작동 되는 중 !
device_lib.list_local_devices() 
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-3-e584e63da696>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# # 파라미터 설정

# %%
X_shape = [20, 21]                            # X 형태 [행, 열] -> 트레이닝 크기
epoch = 100                                  # epoch 횟수

# %% [markdown]
# # Test Data Setting

# %%
# 현재 디렉토리 내에서 파일 경로 설정
path = "./test"
test_file = os.listdir(path)

# 리스트 내 checkpoint가 있으면 제거
if '.ipynb_checkpoints' in test_file:
  test_file.remove('.ipynb_checkpoints')
  
print(test_file) # 경로 내에 모든 파일 출력 ['sino_wmetal.txt']
# Out:
# ['sino_wmetal.txt']

# %%
df = pd.read_table('./test/' + test_file[0], sep = ',', header = None) # Test Data 불러오기

plt.imshow(df); # 테스트 이미지

# %%
### 마스크, metal_line, padding, y_shape 설정 ----------------------------------
mask_value = 200 # 마스크에 설정 된 값
mask_list = [] # 마스크 리스트 만들기

# mask_value에 맞는 부위 mask_list에 추가
for i in range(360):
  temp = []
  for i, k in zip(df.iloc[:, i]== mask_value, df.iloc[:, i].index):
    if i == True:
      temp.append(k)
  mask_list.append(temp)

y_shape = 0 # 예측 범위 변수
padding = 0 # 일자로 만들기 위한 마스크 위, 아래를 채울 패딩 추가
metal_line = [] # mask_list를 따라 한줄씩 선 따기
count = 0
for i in mask_list[:]:
  mid = int((max(i) - min(i))/2)

  # padding의 크기 = 마스크의 크기 / 2
  if mid > padding:
    padding = mid

  if (max(i)-min(i)) % 2 == 0:
    metal_line.append(min(i) + mid)

  else:
    metal_line.append(min(i) + mid + 1)

  count += 1
metal_shift = [i - min(metal_line) for i in metal_line]
### ----------------------------------------------------------------

# 데이터 전처리
for i, j, k in zip(df.columns, metal_shift, metal_line):
      df.iloc[k - 1 - padding : k + padding + 1, i] = 200
      df[i] = df[i].shift(-j, fill_value = 0)
    
y_test_range = [min(df[df.iloc[:, 0] == 200].index), max(df[df.iloc[:, 0] == 200].index) + 1]
y_shape = y_test_range[1] - y_test_range[0]

df.iloc[y_test_range[0] : y_test_range[1], :] = 0
df = df / math.ceil(df.max().max())

df_temp_left = pd.DataFrame()
df_temp_right = pd.DataFrame()
for i in range(int(X_shape[1]/2)):
    df_temp_left[i] = df[0]
    df_temp_right[i] = df[359]

df_left = pd.concat([df_temp_left, df], axis = 1)
df = pd.concat([df_left, df_temp_right], axis = 1)

plt.imshow(df)

df.shape
# Out:
# (256, 380)

# %%
X_test_org, y_test_org = [], [] # X는 입력 변수, y는 출력 변수

# Test Data Cutting
for i in range(df.shape[1] - X_shape[1] + 1):
    X_test_org.append(pd.concat([df.iloc[y_test_range[0] - int(X_shape[0]/2):y_test_range[0], 0+i:X_shape[1]+i], df.iloc[y_test_range[1]:y_test_range[1] + int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))
    if X_shape[1] % 2 == 0:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)])
    else:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)+1])

X_test_org, y_test_org = np.array(X_test_org), np.array(y_test_org) # numpy 형태로 변형하고 reshape

# Conv2D 입력 형태에 맞게 reshape
# RGB 값을 추가 합니다. 흑백으로 설정 하였습니다.
X_test, y_test = X_test_org.reshape(((df.shape[1]-X_shape[1] + 1), X_shape[0], X_shape[1], 1)), y_test_org
print('X_test shape : {}, y_test shape : {}'.format(X_test.shape, y_test.shape))
# Out:
# X_test shape : (360, 20, 21, 1), y_test shape : (360, 12)

# %% [markdown]
# # Training Data Setting

# %%
# 현재 디렉토리 내에서 파일 경로 설정
path = "./train"
file_lst = os.listdir(path)
file_lst.sort()
# 리스트 내 checkpoint가 있으면 제거
if '.ipynb_checkpoints' in file_lst:
  file_lst.remove('.ipynb_checkpoints')
# 경로 내에 모든 파일 출력
print(file_lst) # ['test1.text','test2.text','test3.text','.ipynb_checkpoints','test4.text','test.ipynb','test5.text']

# 경로 내에 각각의 파일을 출력
for file in file_lst:
    filepath = path + '/' + file
    print(file)
# Out:
# ['sino_1.txt', 'sino_2.txt', 'sino_3.txt', 'sino_4.txt', 'sino_5.txt', 'sino_6.txt', 'sino_7.txt', 'sino_8.txt']
# sino_1.txt
# sino_2.txt
# sino_3.txt
# sino_4.txt
# sino_5.txt
# sino_6.txt
# sino_7.txt
# sino_8.txt

# %%
# 이미지 shift 시키는 과정.
for num, file in zip(range(len(file_lst)), file_lst): 
    globals()['df{}'.format(num)] = pd.read_table(path + '/' + file, sep=',', header = None)
    for i, j in zip(globals()['df{}'.format(num)].columns, metal_shift):
      globals()['df{}'.format(num)][i] = globals()['df{}'.format(num)][i].shift(-j, fill_value = 0)
    globals()['df{}'.format(num)] = globals()['df{}'.format(num)] / math.ceil(globals()['df{}'.format(num)].max().max())

# 이미지 양쪽 열 10개씩 늘리는 과정.
for num in range(len(file_lst)):
    df_temp_left = pd.DataFrame()
    df_temp_right = pd.DataFrame()
    for i in range(int(X_shape[1]/2)):
        df_temp_left[i] = globals()['df{}'.format(num)][0]
        df_temp_right[i] = globals()['df{}'.format(num)][359]

    df_left = pd.concat([df_temp_left, globals()['df{}'.format(num)]], axis = 1)
    globals()['df{}'.format(num)] = pd.concat([df_left, df_temp_right], axis = 1)

# %% [markdown]
# 아래 셀 런타임 오래 걸림

# %%
X_train_org, y_train_org = [], [] # X는 입력 변수, y는 출력 변수

# X 형태 (x_shape[0]/2 + x_shape[0]/2, x_shape[1]), y 형태 (y_shape)
for num in notebook.tqdm(range(len(file_lst)), desc='File Count'):
    for i in notebook.tqdm(range(globals()['df{}'.format(num)].shape[1] - X_shape[1] + 1), desc='File Count'):          # i, 열, 1
        for j in range(globals()['df{}'.format(num)].shape[0] - X_shape[0] - y_shape):                         # j, 행, 0
            X_train_org.append(pd.concat([globals()['df{}'.format(num)].iloc[j:j+int(X_shape[0]/2), 0+i:X_shape[1]+i], globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2)+y_shape:j+int(X_shape[0]/2)+y_shape+int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))           # 아래
            if X_shape[1] % 2 == 0:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)])
            else:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)+1])

X_train_org, y_train_org = np.array(X_train_org), np.array(y_train_org) # reshape 하기위해 numpy 형태로 변형

# Conv2D 입력 형태에 맞게 reshape
# RGB 값을 추가 합니다. 흑백으로 설정 하였습니다.
X_train = X_train_org.reshape((len(file_lst)*(df.shape[1]-X_shape[1] + 1)*(df.shape[0]-X_shape[0]-y_shape), X_shape[0], X_shape[1], 1))
y_train = y_train_org
print('X_train shape : {}, y_train shape : {}'.format(X_train.shape, y_train.shape))
# Out:
# File Count:   0%|          | 0/8 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# X_train shape : (645120, 20, 21, 1), y_train shape : (645120, 12)

# %%
len(file_lst), (df.shape[1]-X_shape[1] + 1), (df.shape[0]-X_shape[0]-y_shape) ,20 , 21 , 1
# Out:
# (8, 360, 224, 20, 21, 1)

# %%
X_test_org.shape
# Out:
# (360, 20, 21)

# %% [markdown]
# # 모델

# %%
# model 생성
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(X_shape[0], X_shape[1], 1), padding = 'same'))
# MaxPooling2D(filter)
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(y_shape))
model.summary()

# overfitting을 방지하기 위해서 학습 중 early stop을 수행하기 위한 코드입니다.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

# 모델 검증
# 검증 데이터 손실이 4회 증가하면 학습 조기 종료
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)

# 검증 데이터의 정확도가 이전보다 좋아질 경우에만 모델 저장
mc = keras.callbacks.ModelCheckpoint('./save_model/best_model_shape{}.h5'.format(y_shape), monitor='val_accuracy', mode='max', verbose=1, save_best_only=True) 

# model 구성
model.compile(optimizer='adam',
            loss='mse',
            metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 20, 21, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                102464
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                780
# =================================================================
# Total params: 158,988
# Trainable params: 158,988
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# gpu가 없으면 학습이 오래 걸립니다.

# %%
# 모델 훈련
history = model.fit(X_train, y_train, epochs=epoch, callbacks=[es, mc], validation_data=(X_test, y_test), verbose = 1)

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print(test_acc)   # 정확도
# Out:
# Epoch 1/100
# 20159/20160 [============================>.] - ETA: 0s - loss: 9.5130e-04 - accuracy: 0.3548
# Epoch 00001: val_accuracy improved from -inf to 0.63333, saving model to ./save_model/best_model_shape12.h5
# 20160/20160 [==============================] - 28s 1ms/step - loss: 9.5128e-04 - accuracy: 0.3548 - val_loss: 0.4691 - val_accuracy: 0.6333
# Epoch 2/100
# 20152/20160 [============================>.] - ETA: 0s - loss: 4.3348e-04 - accuracy: 0.3896
# Epoch 00002: val_accuracy improved from 0.63333 to 0.70278, saving model to ./save_model/best_model_shape12.h5
# 20160/20160 [==============================] - 28s 1ms/step - loss: 4.3343e-04 - accuracy: 0.3896 - val_loss: 0.4556 - val_accuracy: 0.7028
# Epoch 3/100
# 20160/20160 [==============================] - ETA: 0s - loss: 3.4961e-04 - accuracy: 0.3977
# Epoch 00003: val_accuracy did not improve from 0.70278
# 20160/20160 [==============================] - 28s 1ms/step - loss: 3.4961e-04 - accuracy: 0.3977 - val_loss: 0.4590 - val_accuracy: 0.6639
# Epoch 4/100
# 20137/20160 [============================>.] - ETA: 0s - loss: 3.0853e-04 - accuracy: 0.4036
# Epoch 00004: val_accuracy did not improve from 0.70278
# 20160/20160 [==============================] - 28s 1ms/step - loss: 3.0852e-04 - accuracy: 0.4036 - val_loss: 0.4780 - val_accuracy: 0.5778
# Epoch 5/100
# 20160/20160 [==============================] - ETA: 0s - loss: 2.8638e-04 - accuracy: 0.4116
# Epoch 00005: val_accuracy improved from 0.70278 to 0.93056, saving model to ./save_model/best_model_shape12.h5
# 20160/20160 [==============================] - 28s 1ms/step - loss: 2.8638e-04 - accuracy: 0.4116 - val_loss: 0.4600 - val_accuracy: 0.9306
# Epoch 6/100
# 20147/20160 [============================>.] - ETA: 0s - loss: 2.7223e-04 - accuracy: 0.4051
# Epoch 00006: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 27s 1ms/step - loss: 2.7217e-04 - accuracy: 0.4052 - val_loss: 0.4634 - val_accuracy: 0.5583
# Epoch 00006: early stopping
# 12/12 - 0s - loss: 0.4634 - accuracy: 0.5583
# 0.5583333373069763

# %%
# 저장된 모델인 'best_model.h5'를 로드하고, 성능을 평가
loaded_model = load_model('./save_model/best_model_shape{}.h5'.format(y_shape))
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))

# 에포크마다 변화하는 훈련 데이터와 검증 데이터(테스트 데이터)의 손실을 시각화
epochs = range(1, len(history.history['accuracy']) + 1)
plt.plot(epochs, history.history['loss'])
plt.plot(epochs, history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show();
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.9306
#
#  테스트 정확도: 0.9306

# %%
# 모델 예측
pred = model.predict(X_test)    # 예측 데이터를 ()안에 넣으면 됩니다.

figure, axes = plt.subplots(nrows=2, ncols=2, figsize = (35, 15))
axes[0][0].set_title('Test Image')
axes[0][0].imshow(y_test_org.T)
axes[0][1].set_title('Pred Image')
axes[0][1].imshow(pred.T)
axes[1][0].set_title('Test Image')
axes[1][0].imshow(df)
df_test_img = df
if X_shape[1] % 2 == 0:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):df.shape[1]-int(X_shape[1]/2)] = pred.T
else:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):df.shape[1]-int(X_shape[1]/2)] = pred.T
axes[1][1].set_title('Pred Image')
axes[1][1].imshow(df_test_img)
figure.colorbar;

figure.tight_layout()
plt.show()

# %% [markdown]
# 예측 결과 원본 데이터에 덮어쓰기

# %%
df_pred = pd.read_table('./test/' + test_file[0], sep = ',', header = None) # 원본 Test Data 불러오기
for i, j, k in zip(df_pred.columns, metal_shift, metal_line):
    df_pred = df_pred / math.ceil(df_pred.max().max())
    df_pred.iloc[k - 1 - padding : k + padding + 1, i] = pred[i]
        
plt.imshow(df_pred)
print('예측 이미지 형태 : {}, 예측 범위 : {}칸'.format(df_pred.shape, y_shape))
# Out:
# pred 이미지 shape : (256, 360)

# %%
# 테스트 정확도 4자리 수로 저장
test_acc = int(round(loaded_model.evaluate(X_test, y_test)[1], 4)*(10**4))
print('test 정확도 : {}%'.format(test_acc*(10**-2)))

# mat 저장
import scipy.io as sio
sio.savemat('./save_img/one_metal_{}.mat'.format(test_acc), {'values' : df_pred.values})

# txt 저장
df_pred.to_csv('./save_img/one_metal_{}.txt'.format(test_acc))
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.9306
# test 정확도 : 93.06%

# %% [markdown]
# # Metal Add

# %%
df_metal1 = pd.read_table('./images/sino_examples/metalsino_2.txt',sep = ',', header = None)
df_metal2 = pd.read_table('./images/sino_examples/metalsino_1.txt',sep = ',', header = None)

figure, axes = plt.subplots(nrows=1, ncols=2, figsize = (35, 15))
axes[0].set_title('Metal1 Image')
axes[0].imshow(df_metal1)
axes[1].set_title('Metal2 Image')
axes[1].imshow(df_metal2);

# %%
df=pd.DataFrame([i for i in df_pred.values])
plt.imshow(df)

# %% [markdown]
# # Metal1 Test Data Setting

# %%
### 마스크, metal_line, padding, y_shape 설정 ----------------------------------
# 예측 했던 데이터 위에 metal 추가
df=pd.DataFrame([i for i in df_pred.values])

mask_value = 200
mask_list = []

# 마스킹 값에 해당하는 부분 예측
for i in range(360):
  temp = []
  for i, k in zip(df_metal1.iloc[:, i]== mask_value, df_metal1.iloc[:, i].index):
    if i == True:
      temp.append(k)
  mask_list.append(temp)

y_shape = 0
padding = 0
metal_line = []
count = 0
for i in mask_list[:]:
  mid = int((max(i) - min(i))/2)

  if mid > padding:
    padding = mid

  if (max(i)-min(i)) % 2 == 0:
    metal_line.append(min(i) + mid)

  else:
    metal_line.append(min(i) + mid + 1)

  count += 1
metal_shift = [i - min(metal_line) for i in metal_line]
### ----------------------------------------------------------------

# %%
# 마스킹 부분 일자로 쉬프트
for i, j, k in zip(df.columns, metal_shift, metal_line):
      df.iloc[k - 1 - padding : k + padding + 1, i] = 200
      df[i] = df[i].shift(-j, fill_value = 0)
    
y_test_range = [min(df[df.iloc[:, 0] == 200].index), max(df[df.iloc[:, 0] == 200].index) + 1]
y_shape = y_test_range[1] - y_test_range[0]

df.iloc[y_test_range[0] : y_test_range[1], :] = 0

# 양쪽 모두 열 (X_shape[1]/2) 개 추가
df_temp_left = pd.DataFrame()
df_temp_right = pd.DataFrame()
for i in range(int(X_shape[1]/2)):
    df_temp_left[i] = df[0]
    df_temp_right[i] = df[359]

df_left = pd.concat([df_temp_left, df], axis = 1)
df = pd.concat([df_left, df_temp_right], axis = 1)

plt.imshow(df)

df.shape
# Out:
# (256, 380)

# %%
X_test_org, y_test_org = [], [] # X는 입력 변수, y는 출력 변수

# Test Data Cutting
for i in range(df.shape[1] - X_shape[1] + 1):
    X_test_org.append(pd.concat([df.iloc[y_test_range[0] - int(X_shape[0]/2):y_test_range[0], 0+i:X_shape[1]+i], df.iloc[y_test_range[1]:y_test_range[1] + int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))
    if X_shape[1] % 2 == 0:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)])
    else:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)+1])

X_test_org, y_test_org = np.array(X_test_org), np.array(y_test_org) # numpy 형태로 변형하고 reshape

# Conv2D 입력 형태에 맞게 reshape
# RGB 값을 추가 합니다. 흑백으로 설정 하였습니다.
X_test, y_test = X_test_org.reshape(((df.shape[1]-X_shape[1] + 1), X_shape[0], X_shape[1], 1)), y_test_org
print('X_test shape : {}, y_test shape : {}'.format(X_test.shape, y_test.shape))
# Out:
# X_test shape : (360, 20, 21, 1), y_test shape : (360, 14)

# %% [markdown]
# # Metal1 Training Data Setting

# %%
# 현재 디렉토리 내에서 파일 경로 설정
path = "./train"
file_lst = os.listdir(path)
file_lst.sort()
# 리스트 내 checkpoint가 있으면 제거
if '.ipynb_checkpoints' in file_lst:
  file_lst.remove('.ipynb_checkpoints')
# 경로 내에 모든 파일 출력
print(file_lst) # ['test1.text','test2.text','test3.text','.ipynb_checkpoints','test4.text','test.ipynb','test5.text']

# 경로 내에 각각의 파일을 출력
for file in file_lst:
    filepath = path + '/' + file
    print(file)

# 이미지 shift 시키는 과정.
for num, file in zip(range(len(file_lst)), file_lst): 
    globals()['df{}'.format(num)] = pd.read_table(path + '/' + file, sep=',', header = None)
    for i, j in zip(globals()['df{}'.format(num)].columns, metal_shift):
      globals()['df{}'.format(num)][i] = globals()['df{}'.format(num)][i].shift(-j, fill_value = 0)
    globals()['df{}'.format(num)] = globals()['df{}'.format(num)] / math.ceil(globals()['df{}'.format(num)].max().max())

# 이미지 양쪽 열 10개씩 늘리는 과정.
for num in range(len(file_lst)):
    df_temp_left = pd.DataFrame()
    df_temp_right = pd.DataFrame()
    for i in range(int(X_shape[1]/2)):
        df_temp_left[i] = globals()['df{}'.format(num)][0]
        df_temp_right[i] = globals()['df{}'.format(num)][359]

    df_left = pd.concat([df_temp_left, globals()['df{}'.format(num)]], axis = 1)
    globals()['df{}'.format(num)] = pd.concat([df_left, df_temp_right], axis = 1)
# Out:
# ['sino_1.txt', 'sino_2.txt', 'sino_3.txt', 'sino_4.txt', 'sino_5.txt', 'sino_6.txt', 'sino_7.txt', 'sino_8.txt']
# sino_1.txt
# sino_2.txt
# sino_3.txt
# sino_4.txt
# sino_5.txt
# sino_6.txt
# sino_7.txt
# sino_8.txt

# %% [markdown]
# 아래 셀 런타임 오래 걸림

# %%
X_train_org, y_train_org = [], [] # X는 입력 변수, y는 출력 변수

# X 형태 (x_shape[0]/2 + x_shape[0]/2, x_shape[1]), y 형태 (y_shape)
for num in notebook.tqdm(range(len(file_lst)), desc='File Count'):
    for i in notebook.tqdm(range(globals()['df{}'.format(num)].shape[1] - X_shape[1] + 1), desc='File Count'):          # i, 열, 1
        for j in range(globals()['df{}'.format(num)].shape[0] - X_shape[0] - y_shape):                         # j, 행, 0
            X_train_org.append(pd.concat([globals()['df{}'.format(num)].iloc[j:j+int(X_shape[0]/2), 0+i:X_shape[1]+i], globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2)+y_shape:j+int(X_shape[0]/2)+y_shape+int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))           # 아래
            if X_shape[1] % 2 == 0:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)])
            else:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)+1])

X_train_org, y_train_org = np.array(X_train_org), np.array(y_train_org) # reshape 하기위해 numpy 형태로 변형

# Conv2D 입력 형태에 맞게 reshape
# RGB 값을 추가 합니다. 흑백으로 설정 하였습니다.
X_train = X_train_org.reshape((len(file_lst)*(df.shape[1]-X_shape[1] + 1)*(df.shape[0]-X_shape[0]-y_shape), X_shape[0], X_shape[1], 1))
y_train = y_train_org
print('X_train shape : {}, y_train shape : {}'.format(X_train.shape, y_train.shape))

len(file_lst), (df.shape[1]-X_shape[1] + 1), (df.shape[0]-X_shape[0]-y_shape) ,20 , 21 , 1

X_test_org.shape
# Out:
# File Count:   0%|          | 0/8 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# X_train shape : (639360, 20, 21, 1), y_train shape : (639360, 14)
# (360, 20, 21)

# %% [markdown]
# # Metal1 모델
# gpu가 없으면 학습이 오래 걸립니다.

# %%
# y_shape에 해당하는 모델이 없으면 실행
# model 생성
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(X_shape[0], X_shape[1], 1), padding = 'same'))
# MaxPooling2D(filter)
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(y_shape))
model.summary()

# overfitting을 방지하기 위해서 학습 중 early stop을 수행하기 위한 코드입니다.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

# 모델 검증
# 검증 데이터 손실이 4회 증가하면 학습 조기 종료
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)

# 검증 데이터의 정확도가 이전보다 좋아질 경우에만 모델 저장
mc = keras.callbacks.ModelCheckpoint('./save_model/best_model_shape{}.h5'.format(y_shape), monitor='val_accuracy', mode='max', verbose=1, save_best_only=True) 

# model 구성
model.compile(optimizer='adam',
            loss='mse',
            metrics=['accuracy'])

# 모델 훈련
history = model.fit(X_train, y_train, epochs=epoch, callbacks=[es, mc], validation_data=(X_test, y_test), verbose = 1)

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print(test_acc)   # 정확도
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 20, 21, 32)        320
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                102464
# _________________________________________________________________
# dense_15 (Dense)             (None, 14)                910
# =================================================================
# Total params: 159,118
# Trainable params: 159,118
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 19957/19980 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.3876
# Epoch 00001: val_accuracy improved from -inf to 0.25000, saving model to ./save_model/best_model_shape14.h5
# 19980/19980 [==============================] - 27s 1ms/step - loss: 0.0011 - accuracy: 0.3876 - val_loss: 0.4900 - val_accuracy: 0.2500
# Epoch 2/100
# 19979/19980 [============================>.] - ETA: 0s - loss: 5.3548e-04 - accuracy: 0.4092
# Epoch 00002: val_accuracy improved from 0.25000 to 0.53333, saving model to ./save_model/best_model_shape14.h5
# 19980/19980 [==============================] - 27s 1ms/step - loss: 5.3549e-04 - accuracy: 0.4092 - val_loss: 0.4427 - val_accuracy: 0.5333
# Epoch 3/100
# 19955/19980 [============================>.] - ETA: 0s - loss: 4.4493e-04 - accuracy: 0.4007
# Epoch 00003: val_accuracy did not improve from 0.53333
# 19980/19980 [==============================] - 27s 1ms/step - loss: 4.4474e-04 - accuracy: 0.4007 - val_loss: 0.4734 - val_accuracy: 0.4556
# Epoch 4/100
# 19954/19980 [============================>.] - ETA: 0s - loss: 3.9810e-04 - accuracy: 0.3999
# Epoch 00004: val_accuracy improved from 0.53333 to 0.66111, saving model to ./save_model/best_model_shape14.h5
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.9801e-04 - accuracy: 0.3999 - val_loss: 0.4699 - val_accuracy: 0.6611
# Epoch 5/100
# 19969/19980 [============================>.] - ETA: 0s - loss: 3.7133e-04 - accuracy: 0.3931
# Epoch 00005: val_accuracy did not improve from 0.66111
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.7132e-04 - accuracy: 0.3930 - val_loss: 0.4650 - val_accuracy: 0.2750
# Epoch 6/100
# 19949/19980 [============================>.] - ETA: 0s - loss: 3.4586e-04 - accuracy: 0.3974
# Epoch 00006: val_accuracy did not improve from 0.66111
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.4572e-04 - accuracy: 0.3973 - val_loss: 0.4601 - val_accuracy: 0.6028
# Epoch 00006: early stopping
# 12/12 - 0s - loss: 0.4601 - accuracy: 0.6028
# 0.6027777791023254

# %% [markdown]
# # 학습된 모델 불러오기

# %%
# 저장된 모델이 있을때 주석 해제 후 실행
# 저장된 모델인 'best_model.h5'를 로드하고, 성능을 평가
loaded_model = load_model('./save_model/best_model_shape{}.h5'.format(y_shape))
loaded_model.summary()
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))

# model 구성
loaded_model.compile(optimizer='adam',
                     loss='mse',
                     metrics=['accuracy'])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 20, 21, 32)        320
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                102464
# _________________________________________________________________
# dense_15 (Dense)             (None, 14)                910
# =================================================================
# Total params: 159,118
# Trainable params: 159,118
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4702 - accuracy: 0.6722
#
#  테스트 정확도: 0.6722

# %% [markdown]
# # 불러온 학습된 모델 추가 학습 시키려면 사용
# gpu가 없으면 학습이 느립니다.

# %%
# 훈련된 모델에 추가 학습 하려면 사용, Matal1 Train Data Setting 부분 실행 해야 함.
history = loaded_model.fit(X_train, y_train, epochs=epoch, callbacks=[es, mc], validation_data=(X_test, y_test), verbose = 1)

test_loss, test_acc = loaded_model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print('테스트 정확도 : %.4f' %test_acc)   # 정확도
# Out:
# Epoch 1/100
# 19945/19980 [============================>.] - ETA: 0s - loss: 3.6638e-04 - accuracy: 0.3957
# Epoch 00001: val_accuracy did not improve from 0.93056
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.6638e-04 - accuracy: 0.3956 - val_loss: 0.4577 - val_accuracy: 0.4833
# Epoch 2/100
# 19972/19980 [============================>.] - ETA: 0s - loss: 3.4363e-04 - accuracy: 0.3933
# Epoch 00002: val_accuracy did not improve from 0.93056
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.4364e-04 - accuracy: 0.3933 - val_loss: 0.4648 - val_accuracy: 0.5500
# Epoch 3/100
# 19949/19980 [============================>.] - ETA: 0s - loss: 3.2747e-04 - accuracy: 0.3981
# Epoch 00003: val_accuracy did not improve from 0.93056
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.2746e-04 - accuracy: 0.3980 - val_loss: 0.4738 - val_accuracy: 0.4833
# Epoch 4/100
# 19945/19980 [============================>.] - ETA: 0s - loss: 3.1467e-04 - accuracy: 0.3948
# Epoch 00004: val_accuracy did not improve from 0.93056
# 19980/19980 [==============================] - 29s 1ms/step - loss: 3.1464e-04 - accuracy: 0.3949 - val_loss: 0.4673 - val_accuracy: 0.4944
# Epoch 5/100
# 19961/19980 [============================>.] - ETA: 0s - loss: 3.0402e-04 - accuracy: 0.3977
# Epoch 00005: val_accuracy did not improve from 0.93056
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.0400e-04 - accuracy: 0.3977 - val_loss: 0.4583 - val_accuracy: 0.5583
# Epoch 00005: early stopping
# 12/12 - 0s - loss: 0.4583 - accuracy: 0.5583
# 테스트 정확도 : 0.5583

# %%
# 에포크마다 변화하는 훈련 데이터와 검증 데이터(테스트 데이터)의 손실을 시각화
epochs = range(1, len(history.history['accuracy']) + 1)
plt.plot(epochs, history.history['loss'])
plt.plot(epochs, history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show();

# %%
# 모델 예측
pred = loaded_model.predict(X_test)    # 예측 데이터를 ()안에 넣으면 됩니다.

figure, axes = plt.subplots(nrows=2, ncols=2, figsize = (35, 15))
axes[0][0].set_title('Test Image')
axes[0][0].imshow(y_test_org.T)
axes[0][1].set_title('Pred Image')
axes[0][1].imshow(pred.T)
axes[1][0].set_title('Test Image')
axes[1][0].imshow(df)
df_test_img = df
if X_shape[1] % 2 == 0:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):df.shape[1]-int(X_shape[1]/2)] = pred.T
else:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):df.shape[1]-int(X_shape[1]/2)] = pred.T
axes[1][1].set_title('Pred Image')
axes[1][1].imshow(df_test_img)
figure.colorbar;

figure.tight_layout()
plt.show()

# %% [markdown]
# 예측 결과 원본 데이터에 덮어쓰기

# %%
for i, j, k in zip(df_pred.columns, metal_shift, metal_line):
    df_pred = df_pred / math.ceil(df_pred.max().max())
    df_pred.iloc[k - 1 - padding : k + padding + 1, i] = pred[i]
        
plt.imshow(df_pred)
print('예측 이미지 형태 : {}, 예측 범위 : {}칸'.format(df_pred.shape, y_shape))
# Out:
# 예측 이미지 형태 : (256, 360), 예측 범위 : 14칸

# %%
# 테스트 정확도 4자리 수로 저장
test_acc = int(round(loaded_model.evaluate(X_test, y_test)[1], 4)*(10**4))
print('test 정확도 : {}%'.format(test_acc*(10**-2)))

# mat 저장
import scipy.io as sio
sio.savemat('./save_img/two_metal_{}.mat'.format(test_acc), {'values' : df_pred.values})

# txt 저장
df_pred.to_csv('./save_img/two_metal_{}.txt'.format(test_acc))
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4583 - accuracy: 0.5583
# test 정확도 : 55.83%

# %% [markdown]
# # Metal2 Test Data Setting

# %%
### 마스크, metal_line, padding, y_shape 설정 ----------------------------------
# 예측 했던 데이터 위에 metal 추가
df=pd.DataFrame([i for i in df_pred.values])

mask_value = 200
mask_list = []

# 마스킹 값에 해당하는 부분 예측
for i in range(360):
  temp = []
  for i, k in zip(df_metal2.iloc[:, i]== mask_value, df_metal2.iloc[:, i].index):
    if i == True:
      temp.append(k)
  mask_list.append(temp)

y_shape = 0
padding = 0
metal_line = []
count = 0
for i in mask_list[:]:
  mid = int((max(i) - min(i))/2)

  if mid > padding:
    padding = mid

  if (max(i)-min(i)) % 2 == 0:
    metal_line.append(min(i) + mid)

  else:
    metal_line.append(min(i) + mid + 1)

  count += 1
metal_shift = [i - min(metal_line) for i in metal_line]
### ----------------------------------------------------------------

# %%
# 마스킹 부분 일자로 쉬프트
for i, j, k in zip(df.columns, metal_shift, metal_line):
      df.iloc[k - 1 - padding : k + padding + 1, i] = 200
      df[i] = df[i].shift(-j, fill_value = 0)
    
y_test_range = [min(df[df.iloc[:, 0] == 200].index), max(df[df.iloc[:, 0] == 200].index) + 1]
y_shape = y_test_range[1] - y_test_range[0]

df.iloc[y_test_range[0] : y_test_range[1], :] = 0

# 양쪽 모두 열 (X_shape[1]/2) 개 추가
df_temp_left = pd.DataFrame()
df_temp_right = pd.DataFrame()
for i in range(int(X_shape[1]/2)):
    df_temp_left[i] = df[0]
    df_temp_right[i] = df[359]

df_left = pd.concat([df_temp_left, df], axis = 1)
df = pd.concat([df_left, df_temp_right], axis = 1)

plt.imshow(df)

df.shape
# Out:
# (256, 380)

# %%
X_test_org, y_test_org = [], [] # X는 입력 변수, y는 출력 변수

# Test Data Cutting
for i in range(df.shape[1] - X_shape[1] + 1):
    X_test_org.append(pd.concat([df.iloc[y_test_range[0] - int(X_shape[0]/2):y_test_range[0], 0+i:X_shape[1]+i], df.iloc[y_test_range[1]:y_test_range[1] + int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))
    if X_shape[1] % 2 == 0:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)])
    else:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)+1])

X_test_org, y_test_org = np.array(X_test_org), np.array(y_test_org) # numpy 형태로 변형하고 reshape

# Conv2D 입력 형태에 맞게 reshape
# RGB 값을 추가 합니다. 흑백으로 설정 하였습니다.
X_test, y_test = X_test_org.reshape(((df.shape[1]-X_shape[1] + 1), X_shape[0], X_shape[1], 1)), y_test_org
print('X_test shape : {}, y_test shape : {}'.format(X_test.shape, y_test.shape))
# Out:
# X_test shape : (360, 20, 21, 1), y_test shape : (360, 12)

# %% [markdown]
# # Metal2 Training Data Setting

# %%
# 현재 디렉토리 내에서 파일 경로 설정
path = "./train"
file_lst = os.listdir(path)
file_lst.sort()
# 리스트 내 checkpoint가 있으면 제거
if '.ipynb_checkpoints' in file_lst:
  file_lst.remove('.ipynb_checkpoints')
# 경로 내에 모든 파일 출력
print(file_lst) # ['test1.text','test2.text','test3.text','.ipynb_checkpoints','test4.text','test.ipynb','test5.text']

# 경로 내에 각각의 파일을 출력
for file in file_lst:
    filepath = path + '/' + file
    print(file)

# 이미지 shift 시키는 과정.
for num, file in zip(range(len(file_lst)), file_lst): 
    globals()['df{}'.format(num)] = pd.read_table(path + '/' + file, sep=',', header = None)
    for i, j in zip(globals()['df{}'.format(num)].columns, metal_shift):
      globals()['df{}'.format(num)][i] = globals()['df{}'.format(num)][i].shift(-j, fill_value = 0)
    globals()['df{}'.format(num)] = globals()['df{}'.format(num)] / math.ceil(globals()['df{}'.format(num)].max().max())

# 이미지 양쪽 열 10개씩 늘리는 과정.
for num in range(len(file_lst)):
    df_temp_left = pd.DataFrame()
    df_temp_right = pd.DataFrame()
    for i in range(int(X_shape[1]/2)):
        df_temp_left[i] = globals()['df{}'.format(num)][0]
        df_temp_right[i] = globals()['df{}'.format(num)][359]

    df_left = pd.concat([df_temp_left, globals()['df{}'.format(num)]], axis = 1)
    globals()['df{}'.format(num)] = pd.concat([df_left, df_temp_right], axis = 1)
# Out:
# ['sino_1.txt', 'sino_2.txt', 'sino_3.txt', 'sino_4.txt', 'sino_5.txt', 'sino_6.txt', 'sino_7.txt', 'sino_8.txt']
# sino_1.txt
# sino_2.txt
# sino_3.txt
# sino_4.txt
# sino_5.txt
# sino_6.txt
# sino_7.txt
# sino_8.txt

# %% [markdown]
# 아래 셀 런타임 오래 걸림

# %%
X_train_org, y_train_org = [], [] # X는 입력 변수, y는 출력 변수

# X 형태 (x_shape[0]/2 + x_shape[0]/2, x_shape[1]), y 형태 (y_shape)
for num in notebook.tqdm(range(len(file_lst)), desc='File Count'):
    for i in notebook.tqdm(range(globals()['df{}'.format(num)].shape[1] - X_shape[1] + 1), desc='File Count'):          # i, 열, 1
        for j in range(globals()['df{}'.format(num)].shape[0] - X_shape[0] - y_shape):                         # j, 행, 0
            X_train_org.append(pd.concat([globals()['df{}'.format(num)].iloc[j:j+int(X_shape[0]/2), 0+i:X_shape[1]+i], globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2)+y_shape:j+int(X_shape[0]/2)+y_shape+int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))           # 아래
            if X_shape[1] % 2 == 0:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)])
            else:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)+1])

X_train_org, y_train_org = np.array(X_train_org), np.array(y_train_org) # reshape 하기위해 numpy 형태로 변형

# Conv2D 입력 형태에 맞게 reshape
# RGB 값을 추가 합니다. 흑백으로 설정 하였습니다.
X_train = X_train_org.reshape((len(file_lst)*(df.shape[1]-X_shape[1] + 1)*(df.shape[0]-X_shape[0]-y_shape), X_shape[0], X_shape[1], 1))
y_train = y_train_org
print('X_train shape : {}, y_train shape : {}'.format(X_train.shape, y_train.shape))

len(file_lst), (df.shape[1]-X_shape[1] + 1), (df.shape[0]-X_shape[0]-y_shape) ,20 , 21 , 1

X_test_org.shape
# Out:
# File Count:   0%|          | 0/8 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# File Count:   0%|          | 0/360 [00:00<?, ?it/s]
# X_train shape : (645120, 20, 21, 1), y_train shape : (645120, 12)
# (360, 20, 21)

# %% [markdown]
# # Metal2 모델
# gpu가 없으면 학습이 오래 걸립니다.

# %%
# y_shape에 해당하는 모델이 없으면 실행
# model 생성
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(X_shape[0], X_shape[1], 1), padding = 'same'))
# MaxPooling2D(filter)
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(y_shape))
model.summary()

# overfitting을 방지하기 위해서 학습 중 early stop을 수행하기 위한 코드입니다.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

# 모델 검증
# 검증 데이터 손실이 4회 증가하면 학습 조기 종료
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)

# 검증 데이터의 정확도가 이전보다 좋아질 경우에만 모델 저장
mc = keras.callbacks.ModelCheckpoint('./save_model/best_model_shape{}.h5'.format(y_shape), monitor='val_accuracy', mode='max', verbose=1, save_best_only=True) 

# model 구성
model.compile(optimizer='adam',
            loss='mse',
            metrics=['accuracy'])

# 모델 훈련
history = model.fit(X_train, y_train, epochs=epoch, callbacks=[es, mc], validation_data=(X_test, y_test), verbose = 1)

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print(test_acc)   # 정확도
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 20, 21, 32)        320
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                102464
# _________________________________________________________________
# dense_15 (Dense)             (None, 14)                910
# =================================================================
# Total params: 159,118
# Trainable params: 159,118
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 19957/19980 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.3876
# Epoch 00001: val_accuracy improved from -inf to 0.25000, saving model to ./save_model/best_model_shape14.h5
# 19980/19980 [==============================] - 27s 1ms/step - loss: 0.0011 - accuracy: 0.3876 - val_loss: 0.4900 - val_accuracy: 0.2500
# Epoch 2/100
# 19979/19980 [============================>.] - ETA: 0s - loss: 5.3548e-04 - accuracy: 0.4092
# Epoch 00002: val_accuracy improved from 0.25000 to 0.53333, saving model to ./save_model/best_model_shape14.h5
# 19980/19980 [==============================] - 27s 1ms/step - loss: 5.3549e-04 - accuracy: 0.4092 - val_loss: 0.4427 - val_accuracy: 0.5333
# Epoch 3/100
# 19955/19980 [============================>.] - ETA: 0s - loss: 4.4493e-04 - accuracy: 0.4007
# Epoch 00003: val_accuracy did not improve from 0.53333
# 19980/19980 [==============================] - 27s 1ms/step - loss: 4.4474e-04 - accuracy: 0.4007 - val_loss: 0.4734 - val_accuracy: 0.4556
# Epoch 4/100
# 19954/19980 [============================>.] - ETA: 0s - loss: 3.9810e-04 - accuracy: 0.3999
# Epoch 00004: val_accuracy improved from 0.53333 to 0.66111, saving model to ./save_model/best_model_shape14.h5
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.9801e-04 - accuracy: 0.3999 - val_loss: 0.4699 - val_accuracy: 0.6611
# Epoch 5/100
# 19969/19980 [============================>.] - ETA: 0s - loss: 3.7133e-04 - accuracy: 0.3931
# Epoch 00005: val_accuracy did not improve from 0.66111
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.7132e-04 - accuracy: 0.3930 - val_loss: 0.4650 - val_accuracy: 0.2750
# Epoch 6/100
# 19949/19980 [============================>.] - ETA: 0s - loss: 3.4586e-04 - accuracy: 0.3974
# Epoch 00006: val_accuracy did not improve from 0.66111
# 19980/19980 [==============================] - 27s 1ms/step - loss: 3.4572e-04 - accuracy: 0.3973 - val_loss: 0.4601 - val_accuracy: 0.6028
# Epoch 00006: early stopping
# 12/12 - 0s - loss: 0.4601 - accuracy: 0.6028
# 0.6027777791023254

# %% [markdown]
# # 학습된 모델에 추가 트레이닝

# %%
# 저장된 모델이 있을때 주석 해제 후 실행
# 저장된 모델인 'best_model.h5'를 로드하고, 성능을 평가
loaded_model = load_model('./save_model/best_model_shape{}.h5'.format(y_shape))
loaded_model.summary()
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))

# model 구성
loaded_model.compile(optimizer='adam',
                     loss='mse',
                     metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 20, 21, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                102464
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                780
# =================================================================
# Total params: 158,988
# Trainable params: 158,988
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.9083
#
#  테스트 정확도: 0.9083

# %% [markdown]
# # 학습된 모델 추가 학습 시키려면 사용

# %%
# 훈련된 모델에 추가 학습 하려면 사용, Matal2 Train Data Setting 부분 실행 해야 함.
history = loaded_model.fit(X_train, y_train, epochs=epoch, callbacks=[es, mc], validation_data=(X_test, y_test), verbose = 1)

test_loss, test_acc = loaded_model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print('테스트 정확도 : %.4f' %test_acc)   # 정확도
# Out:
# Epoch 1/100
# 20138/20160 [============================>.] - ETA: 0s - loss: 2.7033e-04 - accuracy: 0.4071
# Epoch 00001: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 28s 1ms/step - loss: 2.7041e-04 - accuracy: 0.4071 - val_loss: 0.4497 - val_accuracy: 0.7833
# Epoch 2/100
# 20125/20160 [============================>.] - ETA: 0s - loss: 2.5846e-04 - accuracy: 0.4050
# Epoch 00002: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 27s 1ms/step - loss: 2.5838e-04 - accuracy: 0.4050 - val_loss: 0.4330 - val_accuracy: 0.9278
# Epoch 3/100
# 20127/20160 [============================>.] - ETA: 0s - loss: 2.5076e-04 - accuracy: 0.4060
# Epoch 00003: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 27s 1ms/step - loss: 2.5072e-04 - accuracy: 0.4061 - val_loss: 0.4402 - val_accuracy: 0.5889
# Epoch 4/100
# 20147/20160 [============================>.] - ETA: 0s - loss: 2.4225e-04 - accuracy: 0.4075
# Epoch 00004: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 27s 1ms/step - loss: 2.4220e-04 - accuracy: 0.4076 - val_loss: 0.4527 - val_accuracy: 0.5028
# Epoch 5/100
# 20131/20160 [============================>.] - ETA: 0s - loss: 2.3728e-04 - accuracy: 0.4062
# Epoch 00005: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 27s 1ms/step - loss: 2.3723e-04 - accuracy: 0.4061 - val_loss: 0.4446 - val_accuracy: 0.6167
# Epoch 6/100
# 20148/20160 [============================>.] - ETA: 0s - loss: 2.3011e-04 - accuracy: 0.4114
# Epoch 00006: val_accuracy did not improve from 0.93056
# 20160/20160 [==============================] - 27s 1ms/step - loss: 2.3012e-04 - accuracy: 0.4113 - val_loss: 0.4468 - val_accuracy: 0.4667
# Epoch 00006: early stopping
# 12/12 - 0s - loss: 0.4468 - accuracy: 0.4667
# 테스트 정확도 : 0.4667

# %%
# 에포크마다 변화하는 훈련 데이터와 검증 데이터(테스트 데이터)의 손실을 시각화
epochs = range(1, len(history.history['accuracy']) + 1)
plt.plot(epochs, history.history['loss'])
plt.plot(epochs, history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show();

# %%
# 모델 예측
pred = loaded_model.predict(X_test)    # 예측 데이터를 ()안에 넣으면 됩니다.

figure, axes = plt.subplots(nrows=2, ncols=2, figsize = (35, 15))
axes[0][0].set_title('Test Image')
axes[0][0].imshow(y_test_org.T)
axes[0][1].set_title('Pred Image')
axes[0][1].imshow(pred.T)
axes[1][0].set_title('Test Image')
axes[1][0].imshow(df)
df_test_img = df
if X_shape[1] % 2 == 0:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):df.shape[1]-int(X_shape[1]/2)] = pred.T
else:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):df.shape[1]-int(X_shape[1]/2)] = pred.T
axes[1][1].set_title('Pred Image')
axes[1][1].imshow(df_test_img)
figure.colorbar;

figure.tight_layout()
plt.show()

# %% [markdown]
# 예측 결과 원본 데이터에 덮어쓰기

# %%
for i, j, k in zip(df_pred.columns, metal_shift, metal_line):
    df_pred = df_pred / math.ceil(df_pred.max().max())
    df_pred.iloc[k - 1 - padding : k + padding + 1, i] = pred[i]
        
plt.imshow(df_pred)
print('예측 이미지 형태 : {}, 예측 범위 : {}칸'.format(df_pred.shape, y_shape))
# Out:
# 예측 이미지 형태 : (256, 360), 예측 범위 : 12칸

# %%
# 테스트 정확도 4자리 수로 저장
test_acc = int(round(loaded_model.evaluate(X_test, y_test)[1], 4)*(10**4))
print('test 정확도 : {}%'.format(test_acc*(10**-2)))

# mat 저장
import scipy.io as sio
sio.savemat('./save_img/three_metal_{}.mat'.format(test_acc), {'values' : df_pred.values})

# txt 저장
df_pred.to_csv('./save_img/three_metal_{}.txt'.format(test_acc))
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.4667
# test 정확도 : 46.67%
