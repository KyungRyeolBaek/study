# %% [markdown]
# <a href="https://colab.research.google.com/github/KyungRyeolBaek/study/blob/main/AI%20study/%EC%B9%98%EC%95%84/tooth_CNN_210815.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tooth_CNN

# %%
import tensorflow as tf
# Ture가 나와야 GPU가 작동 되는 중 !
from tensorflow.python.client import device_lib 
device_lib.list_local_devices() 
tf.test.is_gpu_available()
# Out:
# 2021-08-19 10:10:44.121554: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from tensorflow.keras import datasets, layers, models
from scipy import io

### 마스크, metal_line, padding, y_shape 설정 ----------------------------------
df_line = pd.read_table('../images/sino_examples/metal_point2.txt', sep = ',', header = None)
df = pd.read_table('../images/sino_examples/Rsino_wmetal.txt', sep = ',', header = None)

mask_list = []

#for i in range(360):
#  temp = []
#  for i, k in zip(df.iloc[:, i]== 200, df.iloc[:, i].index):
#    if i == True:
#      temp.append(k)
#  mask_list.append(temp)

y_shape = 12
padding = 0
metal_line = []
count = 0
for i in mask_list[:]:
  mid = int((max(i) - min(i))/2)

  if max(i) - min(i) > y_shape:
    y_shape = max(i) - min(i)

  if mid > padding:
    padding = mid

  if (max(i)-min(i)) % 2 == 0:
    metal_line.append(min(i) + mid)

  else:
    metal_line.append(min(i) + mid + 1)

  count += 1
metal_shift = [i - min(metal_line) for i in metal_line]
### ----------------------------------------------------------------

# parameter
image_num = [0, 1, 2]       # 전체 이미지
train_image_num = [1]    # 트레이닝 이미지 범위 [1, 2, 3, 4, 5, 6, 7, 8]
# test_image_num = 0                            # 테스트 이미지 숫자 [0]
X_shape = [10, 11]                            # X 형태 [행, 열] -> 트레이닝 크기
# y_shape = 5                                   # y 형태 -> 트레이닝 결과 크기
# y_test_range = [100, 110]                     # y_test 예측 범위 [100 ~ 110]
epoch = 500                                  # epoch 횟수

# metal_line = pd.read_table('./images/sino_examples/metal_point.txt', sep = ',', header = None)


#for i, j, k in zip(df.columns, metal_shift, metal_line):
#      df.iloc[k - 1 - padding : k + padding + 1, i] = 200
#      df[i] = df[i].shift(-j, fill_value = 0)
    
#y_test_range = [min(df[df.iloc[:, 0] == 200].index), max(df[df.iloc[:, 0] == 200].index)]
y_test_range = [110, 122]
df.iloc[y_test_range[0] : y_test_range[1] + 1, :] = 0
df = df / math.ceil(df.max().max())
    
plt.imshow(df)

df.shape
# Out:
# (181, 360)

# %%
y_test_range
# Out:
# [110, 121]

# %%
for num in image_num: 
    globals()['df{}'.format(num)] = pd.read_table('../images/sino_examples/sino_{}.txt'.format(num),sep=',', header = None)
 #   for i, j in zip(globals()['df{}'.format(num)].columns, metal_shift):
 #     globals()['df{}'.format(num)][i] = globals()['df{}'.format(num)][i].shift(-j, fill_value = 0)
    globals()['df{}'.format(num)] = globals()['df{}'.format(num)] / math.ceil(globals()['df{}'.format(num)].max().max())


# train셋, test셋으로 나누어 줍니다. X는 입력 변수, y는 출력 변수
X_train_org, X_test_org, y_train_org, y_test_org = [], [], [], []

# X 형태 (x_shape[0]/2 + x_shape[0]/2, x_shape[1]), y 형태 (y_shape)
for num in train_image_num:
    for i in range(360 - X_shape[1]):                             # i, 열, 1
        for j in range(256 - X_shape[0] - y_shape):                # j, 행, 0
            X_train_org.append(pd.concat([globals()['df{}'.format(num)].iloc[j:j+int(X_shape[0]/2), 0+i:X_shape[1]+i], globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2)+y_shape:j+int(X_shape[0]/2)+y_shape+int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))           # 아래
            if X_shape[1] % 2 == 0:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)])
            else:
                y_train_org.append(globals()['df{}'.format(num)].iloc[j+int(X_shape[0]/2):j+int(X_shape[0]/2)+y_shape, i+int(X_shape[1]/2)+1])

for i in range(360 - X_shape[1]):
    X_test_org.append(pd.concat([df.iloc[y_test_range[0] - int(X_shape[0]/2):y_test_range[0], 0+i:X_shape[1]+i], df.iloc[y_test_range[1]:y_test_range[1] + int(X_shape[0]/2), 0+i:X_shape[1]+i]], axis = 0))
    if X_shape[1] % 2 == 0:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)])
    else:
        y_test_org.append(df.iloc[y_test_range[0]:y_test_range[1], i+int(X_shape[1]/2)+1])

X_train_org, X_test_org, y_train_org, y_test_org = np.array(X_train_org), np.array(X_test_org), np.array(y_train_org), np.array(y_test_org)

# RGB 값을 추가 합니다. 우선 흑백으로 설정 하였습니다.
# train 형태 : ((8*354*245, x_shape[0], x_shape[1], 1)), test 형태 : ((354, x_shape[0], x_shape[1], 1))
# tensorflow는 3차원만 지원하므로 3차원 형태로 reshape 해줘야 합니다.
X_train = X_train_org.reshape((len(train_image_num)*(360-X_shape[1])*(256-X_shape[0]-y_shape), X_shape[0], X_shape[1], 1))
X_test = X_test_org.reshape(((360-X_shape[1]), X_shape[0], X_shape[1], 1))
y_train = y_train_org
y_test = y_test_org

# %%
df1.shape
# Out:
# (256, 360)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(X_shape[0], X_shape[1], 1)))
# MaxPooling2D(filter)
#model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.Conv2D(64, (3, 3), activation='relu'))
#model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(y_shape))
model.summary()


# model 구성
model.compile(optimizer='adam',
            loss='mse',
            metrics=['accuracy'])

model.fit(X_train, y_train, epochs=epoch, verbose = 1)

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print(test_acc)   # 정확도

# 모델 예측
pred = model.predict(X_test)    # 예측 데이터를 ()안에 넣으면 됩니다.

figure, axes = plt.subplots(nrows=2, ncols=2, figsize = (35, 15))
axes[0][0].set_title('Test Image')
axes[0][0].imshow(y_test_org.T)
axes[0][1].set_title('Pred Image')
axes[0][1].imshow(pred.T)
axes[1][0].set_title('Test Image')
axes[1][0].imshow(df)
df_test_img = df
if X_shape[1] % 2 == 0:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):360-int(X_shape[1]/2)] = pred.T
else:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2)+1:360-int(X_shape[1]/2)] = pred.T
axes[1][1].set_title('Pred Image')
axes[1][1].imshow(df_test_img)
figure.colorbar;

figure.tight_layout()
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 8, 9, 32)          320
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 7, 64)          18496
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2688)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                172096
# _________________________________________________________________
# dense_9 (Dense)              (None, 12)                780
# =================================================================
# Total params: 191,692
# Trainable params: 191,692
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 2553/2553 [==============================] - 12s 4ms/step - loss: 0.0047 - accuracy: 0.2828
# Epoch 2/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 3.1614e-04 - accuracy: 0.3791
# Epoch 3/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 2.5119e-04 - accuracy: 0.4052
# Epoch 4/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 2.4407e-04 - accuracy: 0.4500
# Epoch 5/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 2.0320e-04 - accuracy: 0.4179
# Epoch 6/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.9394e-04 - accuracy: 0.3663
# Epoch 7/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.8060e-04 - accuracy: 0.3846
# Epoch 8/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.7026e-04 - accuracy: 0.4225
# Epoch 9/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.7871e-04 - accuracy: 0.4352
# Epoch 10/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.5423e-04 - accuracy: 0.4024
# Epoch 11/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.3775e-04 - accuracy: 0.4106
# Epoch 12/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.3566e-04 - accuracy: 0.4126
# Epoch 13/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.3042e-04 - accuracy: 0.4150
# Epoch 14/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.3618e-04 - accuracy: 0.3998
# Epoch 15/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.3410e-04 - accuracy: 0.4164
# Epoch 16/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.2522e-04 - accuracy: 0.4305
# Epoch 17/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1413e-04 - accuracy: 0.4284
# Epoch 18/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1658e-04 - accuracy: 0.4358
# Epoch 19/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1557e-04 - accuracy: 0.4313
# Epoch 20/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1014e-04 - accuracy: 0.4254
# Epoch 21/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1114e-04 - accuracy: 0.4087
# Epoch 22/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1195e-04 - accuracy: 0.4227
# Epoch 23/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.0992e-04 - accuracy: 0.4262
# Epoch 24/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.0453e-04 - accuracy: 0.4297
# Epoch 25/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.1254e-04 - accuracy: 0.4287
# Epoch 26/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.0451e-04 - accuracy: 0.4300
# Epoch 27/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.0132e-04 - accuracy: 0.4219
# Epoch 28/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.6029e-05 - accuracy: 0.4139
# Epoch 29/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.9034e-05 - accuracy: 0.4316
# Epoch 30/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.4550e-05 - accuracy: 0.4184
# Epoch 31/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.2431e-05 - accuracy: 0.4265
# Epoch 32/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.7845e-05 - accuracy: 0.4470
# Epoch 33/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.5112e-05 - accuracy: 0.4381
# Epoch 34/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.5625e-05 - accuracy: 0.4218
# Epoch 35/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.7333e-05 - accuracy: 0.4199
# Epoch 36/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.6713e-05 - accuracy: 0.4403
# Epoch 37/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.8857e-05 - accuracy: 0.4324
# Epoch 38/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.5740e-05 - accuracy: 0.4251
# Epoch 39/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.1863e-05 - accuracy: 0.4401
# Epoch 40/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 9.0164e-05 - accuracy: 0.4269
# Epoch 41/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.6901e-05 - accuracy: 0.4350
# Epoch 42/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.5298e-05 - accuracy: 0.4519
# Epoch 43/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.5982e-05 - accuracy: 0.4510
# Epoch 44/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.8456e-05 - accuracy: 0.4321
# Epoch 45/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 8.6589e-05 - accuracy: 0.4284
# Epoch 46/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.8326e-05 - accuracy: 0.4391
# Epoch 47/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.6274e-05 - accuracy: 0.4394
# Epoch 48/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.6517e-05 - accuracy: 0.4410
# Epoch 49/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.2974e-05 - accuracy: 0.4472
# Epoch 50/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 1.0149e-04 - accuracy: 0.4389
# Epoch 51/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.4491e-05 - accuracy: 0.4316
# Epoch 52/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.6572e-05 - accuracy: 0.4410
# Epoch 53/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.6878e-05 - accuracy: 0.4368
# Epoch 54/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.2412e-05 - accuracy: 0.4463
# Epoch 55/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.3092e-05 - accuracy: 0.4602
# Epoch 56/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.8708e-05 - accuracy: 0.4421
# Epoch 57/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.1853e-05 - accuracy: 0.4520
# Epoch 58/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.3413e-05 - accuracy: 0.4651
# Epoch 59/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.3089e-05 - accuracy: 0.4554
# Epoch 60/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.2649e-05 - accuracy: 0.4257
# Epoch 61/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.2343e-05 - accuracy: 0.4552
# Epoch 62/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.6862e-05 - accuracy: 0.4524
# Epoch 63/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.9109e-05 - accuracy: 0.4529
# Epoch 64/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.8390e-05 - accuracy: 0.4475
# Epoch 65/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.7032e-05 - accuracy: 0.4589
# Epoch 66/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.9132e-05 - accuracy: 0.4504
# Epoch 67/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.1465e-05 - accuracy: 0.4573
# Epoch 68/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.4788e-05 - accuracy: 0.4365
# Epoch 69/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.5093e-05 - accuracy: 0.4494
# Epoch 70/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.8601e-05 - accuracy: 0.4604
# Epoch 71/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.9030e-05 - accuracy: 0.4497
# Epoch 72/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.9853e-05 - accuracy: 0.4459
# Epoch 73/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 7.1423e-05 - accuracy: 0.4630
# Epoch 74/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.8482e-05 - accuracy: 0.4612
# Epoch 75/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.7336e-05 - accuracy: 0.4524
# Epoch 76/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.6714e-05 - accuracy: 0.4433
# Epoch 77/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.5845e-05 - accuracy: 0.4563
# Epoch 78/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.4450e-05 - accuracy: 0.4425
# Epoch 79/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.0936e-05 - accuracy: 0.4410
# Epoch 80/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.4738e-05 - accuracy: 0.4552
# Epoch 81/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.3637e-05 - accuracy: 0.4511
# Epoch 82/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.4534e-05 - accuracy: 0.4574
# Epoch 83/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.1965e-05 - accuracy: 0.4370
# Epoch 84/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.5160e-05 - accuracy: 0.4513
# Epoch 85/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2419e-05 - accuracy: 0.4329
# Epoch 86/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.4664e-05 - accuracy: 0.4350
# Epoch 87/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.4992e-05 - accuracy: 0.4472
# Epoch 88/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8728e-05 - accuracy: 0.4463
# Epoch 89/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.3659e-05 - accuracy: 0.4441
# Epoch 90/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.9311e-05 - accuracy: 0.4670
# Epoch 91/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2101e-05 - accuracy: 0.4555
# Epoch 92/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2878e-05 - accuracy: 0.4522
# Epoch 93/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8087e-05 - accuracy: 0.4545
# Epoch 94/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.1482e-05 - accuracy: 0.4714
# Epoch 95/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2905e-05 - accuracy: 0.4666
# Epoch 96/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2264e-05 - accuracy: 0.4560
# Epoch 97/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.7831e-05 - accuracy: 0.4682
# Epoch 98/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.1579e-05 - accuracy: 0.4530
# Epoch 99/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8257e-05 - accuracy: 0.4564
# Epoch 100/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2057e-05 - accuracy: 0.4631
# Epoch 101/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.9519e-05 - accuracy: 0.4593
# Epoch 102/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.0927e-05 - accuracy: 0.4680
# Epoch 103/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8608e-05 - accuracy: 0.4498
# Epoch 104/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.7530e-05 - accuracy: 0.4403
# Epoch 105/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5494e-05 - accuracy: 0.4402
# Epoch 106/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.1206e-05 - accuracy: 0.4506
# Epoch 107/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.7328e-05 - accuracy: 0.4416
# Epoch 108/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.2108e-05 - accuracy: 0.4590
# Epoch 109/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.9258e-05 - accuracy: 0.4704
# Epoch 110/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6000e-05 - accuracy: 0.4505
# Epoch 111/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.0989e-05 - accuracy: 0.4664
# Epoch 112/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.0983e-05 - accuracy: 0.4763
# Epoch 113/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.0563e-05 - accuracy: 0.4781
# Epoch 114/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5390e-05 - accuracy: 0.4563
# Epoch 115/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.9574e-05 - accuracy: 0.4709
# Epoch 116/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6945e-05 - accuracy: 0.4767
# Epoch 117/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5766e-05 - accuracy: 0.4544
# Epoch 118/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8546e-05 - accuracy: 0.4406
# Epoch 119/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6519e-05 - accuracy: 0.4781
# Epoch 120/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4868e-05 - accuracy: 0.4709
# Epoch 121/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6234e-05 - accuracy: 0.4799
# Epoch 122/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5208e-05 - accuracy: 0.4746
# Epoch 123/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.7513e-05 - accuracy: 0.4538
# Epoch 124/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5361e-05 - accuracy: 0.4804
# Epoch 125/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6488e-05 - accuracy: 0.4661
# Epoch 126/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3899e-05 - accuracy: 0.4589
# Epoch 127/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4068e-05 - accuracy: 0.4667
# Epoch 128/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.9324e-05 - accuracy: 0.4703
# Epoch 129/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.0338e-05 - accuracy: 0.4683
# Epoch 130/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5290e-05 - accuracy: 0.4709
# Epoch 131/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5268e-05 - accuracy: 0.4739
# Epoch 132/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4785e-05 - accuracy: 0.4524
# Epoch 133/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8133e-05 - accuracy: 0.4751
# Epoch 134/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6963e-05 - accuracy: 0.4675
# Epoch 135/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.9951e-05 - accuracy: 0.4677
# Epoch 136/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5577e-05 - accuracy: 0.4761
# Epoch 137/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3747e-05 - accuracy: 0.4784
# Epoch 138/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8832e-05 - accuracy: 0.4713
# Epoch 139/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4801e-05 - accuracy: 0.4607
# Epoch 140/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5352e-05 - accuracy: 0.4732
# Epoch 141/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2672e-05 - accuracy: 0.4738
# Epoch 142/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2822e-05 - accuracy: 0.4623
# Epoch 143/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5131e-05 - accuracy: 0.4653
# Epoch 144/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4350e-05 - accuracy: 0.4657
# Epoch 145/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2577e-05 - accuracy: 0.4494
# Epoch 146/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5086e-05 - accuracy: 0.4575
# Epoch 147/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6072e-05 - accuracy: 0.4848
# Epoch 148/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4629e-05 - accuracy: 0.4732
# Epoch 149/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.8825e-05 - accuracy: 0.4637
# Epoch 150/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1129e-05 - accuracy: 0.4740
# Epoch 151/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2385e-05 - accuracy: 0.4702
# Epoch 152/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2545e-05 - accuracy: 0.4710
# Epoch 153/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3689e-05 - accuracy: 0.4767
# Epoch 154/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1673e-05 - accuracy: 0.4695
# Epoch 155/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9633e-05 - accuracy: 0.4761
# Epoch 156/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2839e-05 - accuracy: 0.4762
# Epoch 157/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5115e-05 - accuracy: 0.4673
# Epoch 158/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6809e-05 - accuracy: 0.4705
# Epoch 159/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2009e-05 - accuracy: 0.4769
# Epoch 160/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2833e-05 - accuracy: 0.4659
# Epoch 161/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3641e-05 - accuracy: 0.4517
# Epoch 162/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3372e-05 - accuracy: 0.4620
# Epoch 163/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3057e-05 - accuracy: 0.4950
# Epoch 164/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5453e-05 - accuracy: 0.4722
# Epoch 165/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2133e-05 - accuracy: 0.4683
# Epoch 166/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3158e-05 - accuracy: 0.4767
# Epoch 167/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3490e-05 - accuracy: 0.4723
# Epoch 168/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3013e-05 - accuracy: 0.4662
# Epoch 169/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1806e-05 - accuracy: 0.4794
# Epoch 170/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2629e-05 - accuracy: 0.4622
# Epoch 171/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.7065e-05 - accuracy: 0.4568
# Epoch 172/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0759e-05 - accuracy: 0.4762
# Epoch 173/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2845e-05 - accuracy: 0.4576
# Epoch 174/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5792e-05 - accuracy: 0.4727
# Epoch 175/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2017e-05 - accuracy: 0.4607
# Epoch 176/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9985e-05 - accuracy: 0.4679
# Epoch 177/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9286e-05 - accuracy: 0.4660
# Epoch 178/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0556e-05 - accuracy: 0.4661
# Epoch 179/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9878e-05 - accuracy: 0.4775
# Epoch 180/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2768e-05 - accuracy: 0.4728
# Epoch 181/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3642e-05 - accuracy: 0.4496
# Epoch 182/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1629e-05 - accuracy: 0.4608
# Epoch 183/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1437e-05 - accuracy: 0.4537
# Epoch 184/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8641e-05 - accuracy: 0.4493
# Epoch 185/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3959e-05 - accuracy: 0.4738
# Epoch 186/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0294e-05 - accuracy: 0.4600
# Epoch 187/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1786e-05 - accuracy: 0.4591
# Epoch 188/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2341e-05 - accuracy: 0.4578
# Epoch 189/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0863e-05 - accuracy: 0.4855
# Epoch 190/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9827e-05 - accuracy: 0.4824
# Epoch 191/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3572e-05 - accuracy: 0.4604
# Epoch 192/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0569e-05 - accuracy: 0.4578
# Epoch 193/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1178e-05 - accuracy: 0.4685
# Epoch 194/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0254e-05 - accuracy: 0.4780
# Epoch 195/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2375e-05 - accuracy: 0.4659
# Epoch 196/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4483e-05 - accuracy: 0.4667
# Epoch 197/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1642e-05 - accuracy: 0.4826
# Epoch 198/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9122e-05 - accuracy: 0.4768
# Epoch 199/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6534e-05 - accuracy: 0.4654
# Epoch 200/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9671e-05 - accuracy: 0.4721
# Epoch 201/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6938e-05 - accuracy: 0.4777
# Epoch 202/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8776e-05 - accuracy: 0.4758
# Epoch 203/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1066e-05 - accuracy: 0.4640
# Epoch 204/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3196e-05 - accuracy: 0.4836
# Epoch 205/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2153e-05 - accuracy: 0.4751
# Epoch 206/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0163e-05 - accuracy: 0.4590
# Epoch 207/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9704e-05 - accuracy: 0.4755
# Epoch 208/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1318e-05 - accuracy: 0.4695
# Epoch 209/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0094e-05 - accuracy: 0.4684
# Epoch 210/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8478e-05 - accuracy: 0.4587
# Epoch 211/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9980e-05 - accuracy: 0.4645
# Epoch 212/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9407e-05 - accuracy: 0.4535
# Epoch 213/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9626e-05 - accuracy: 0.4835
# Epoch 214/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9330e-05 - accuracy: 0.4740
# Epoch 215/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8788e-05 - accuracy: 0.4697
# Epoch 216/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7427e-05 - accuracy: 0.4533
# Epoch 217/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7079e-05 - accuracy: 0.4729
# Epoch 218/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5720e-05 - accuracy: 0.4685
# Epoch 219/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0274e-05 - accuracy: 0.4709
# Epoch 220/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9303e-05 - accuracy: 0.4792
# Epoch 221/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2342e-05 - accuracy: 0.4872
# Epoch 222/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9289e-05 - accuracy: 0.4643
# Epoch 223/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2014e-05 - accuracy: 0.4808
# Epoch 224/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0934e-05 - accuracy: 0.4794
# Epoch 225/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0152e-05 - accuracy: 0.4674
# Epoch 226/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8295e-05 - accuracy: 0.4770
# Epoch 227/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8256e-05 - accuracy: 0.4568
# Epoch 228/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1238e-05 - accuracy: 0.4925
# Epoch 229/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9731e-05 - accuracy: 0.4669
# Epoch 230/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0717e-05 - accuracy: 0.4681
# Epoch 231/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5737e-05 - accuracy: 0.4645
# Epoch 232/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9098e-05 - accuracy: 0.4868
# Epoch 233/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2976e-05 - accuracy: 0.4694
# Epoch 234/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 6.6180e-05 - accuracy: 0.4856
# Epoch 235/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7252e-05 - accuracy: 0.4695
# Epoch 236/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8399e-05 - accuracy: 0.4791
# Epoch 237/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1745e-05 - accuracy: 0.4821
# Epoch 238/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7291e-05 - accuracy: 0.4783
# Epoch 239/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8764e-05 - accuracy: 0.4560
# Epoch 240/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5665e-05 - accuracy: 0.4785
# Epoch 241/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1206e-05 - accuracy: 0.4747
# Epoch 242/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8623e-05 - accuracy: 0.4815
# Epoch 243/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9631e-05 - accuracy: 0.4826
# Epoch 244/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8028e-05 - accuracy: 0.4596
# Epoch 245/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6018e-05 - accuracy: 0.4790
# Epoch 246/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8273e-05 - accuracy: 0.4655
# Epoch 247/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2482e-05 - accuracy: 0.4845
# Epoch 248/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1164e-05 - accuracy: 0.4798
# Epoch 249/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6735e-05 - accuracy: 0.4734
# Epoch 250/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6184e-05 - accuracy: 0.4843
# Epoch 251/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8407e-05 - accuracy: 0.4765
# Epoch 252/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8658e-05 - accuracy: 0.4853
# Epoch 253/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7560e-05 - accuracy: 0.4672
# Epoch 254/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9220e-05 - accuracy: 0.4722
# Epoch 255/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8371e-05 - accuracy: 0.4789
# Epoch 256/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8179e-05 - accuracy: 0.4746
# Epoch 257/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7901e-05 - accuracy: 0.4912
# Epoch 258/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.6557e-05 - accuracy: 0.4818
# Epoch 259/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8693e-05 - accuracy: 0.4962
# Epoch 260/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2023e-05 - accuracy: 0.4868
# Epoch 261/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7496e-05 - accuracy: 0.4810
# Epoch 262/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6235e-05 - accuracy: 0.4603
# Epoch 263/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9178e-05 - accuracy: 0.4727
# Epoch 264/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8743e-05 - accuracy: 0.4549
# Epoch 265/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6738e-05 - accuracy: 0.4755
# Epoch 266/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7879e-05 - accuracy: 0.4698
# Epoch 267/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2643e-05 - accuracy: 0.4780
# Epoch 268/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6901e-05 - accuracy: 0.4873
# Epoch 269/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7867e-05 - accuracy: 0.4800
# Epoch 270/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5763e-05 - accuracy: 0.4646
# Epoch 271/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8331e-05 - accuracy: 0.4792
# Epoch 272/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6274e-05 - accuracy: 0.4693
# Epoch 273/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.3636e-05 - accuracy: 0.4559
# Epoch 274/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9415e-05 - accuracy: 0.4690
# Epoch 275/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6259e-05 - accuracy: 0.4770
# Epoch 276/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6113e-05 - accuracy: 0.4840
# Epoch 277/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6931e-05 - accuracy: 0.4762
# Epoch 278/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8702e-05 - accuracy: 0.4786
# Epoch 279/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0163e-05 - accuracy: 0.4712
# Epoch 280/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6388e-05 - accuracy: 0.4797
# Epoch 281/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6749e-05 - accuracy: 0.4725
# Epoch 282/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7247e-05 - accuracy: 0.4733
# Epoch 283/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5660e-05 - accuracy: 0.4857
# Epoch 284/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5961e-05 - accuracy: 0.4789
# Epoch 285/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9019e-05 - accuracy: 0.4864
# Epoch 286/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1307e-05 - accuracy: 0.4697
# Epoch 287/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9238e-05 - accuracy: 0.4779
# Epoch 288/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8694e-05 - accuracy: 0.4643
# Epoch 289/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9937e-05 - accuracy: 0.4778
# Epoch 290/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8399e-05 - accuracy: 0.4778
# Epoch 291/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6878e-05 - accuracy: 0.4854
# Epoch 292/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8176e-05 - accuracy: 0.4817
# Epoch 293/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.4118e-05 - accuracy: 0.4705
# Epoch 294/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8488e-05 - accuracy: 0.4651
# Epoch 295/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6965e-05 - accuracy: 0.4734
# Epoch 296/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7411e-05 - accuracy: 0.4943
# Epoch 297/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6270e-05 - accuracy: 0.4740
# Epoch 298/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.4338e-05 - accuracy: 0.4800
# Epoch 299/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6315e-05 - accuracy: 0.4604
# Epoch 300/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7441e-05 - accuracy: 0.4786
# Epoch 301/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5278e-05 - accuracy: 0.4716
# Epoch 302/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1935e-05 - accuracy: 0.4930
# Epoch 303/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5330e-05 - accuracy: 0.4879
# Epoch 304/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1195e-05 - accuracy: 0.4717
# Epoch 305/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2127e-05 - accuracy: 0.4850
# Epoch 306/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.4716e-05 - accuracy: 0.4736
# Epoch 307/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.9937e-05 - accuracy: 0.4706
# Epoch 308/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7354e-05 - accuracy: 0.4667
# Epoch 309/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.5272e-05 - accuracy: 0.4928
# Epoch 310/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7049e-05 - accuracy: 0.4886
# Epoch 311/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0862e-05 - accuracy: 0.4695
# Epoch 312/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6486e-05 - accuracy: 0.4664
# Epoch 313/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5239e-05 - accuracy: 0.4616
# Epoch 314/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6131e-05 - accuracy: 0.4744
# Epoch 315/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.4878e-05 - accuracy: 0.4814
# Epoch 316/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7747e-05 - accuracy: 0.4930
# Epoch 317/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.0743e-05 - accuracy: 0.4879
# Epoch 318/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5253e-05 - accuracy: 0.4850
# Epoch 319/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2112e-05 - accuracy: 0.4895
# Epoch 320/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8903e-05 - accuracy: 0.4838
# Epoch 321/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.6294e-05 - accuracy: 0.4796
# Epoch 322/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.1022e-05 - accuracy: 0.4778
# Epoch 323/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.5431e-05 - accuracy: 0.4736
# Epoch 324/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8314e-05 - accuracy: 0.4753
# Epoch 325/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.3409e-05 - accuracy: 0.4829
# Epoch 326/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.2830e-05 - accuracy: 0.4983
# Epoch 327/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 5.3748e-05 - accuracy: 0.4831
# Epoch 328/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.8955e-05 - accuracy: 0.4772
# Epoch 329/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7892e-05 - accuracy: 0.4806
# Epoch 330/500
# 2553/2553 [==============================] - 11s 4ms/step - loss: 4.7473e-05 - accuracy: 0.4847
# Epoch 331/500
#   50/2553 [..............................] - ETA: 10s - loss: 3.6215e-05 - accuracy: 0.5217

# %%
# 중간에 돌아가던 도중 끊겨서 이어서 남은 5개만 더 돌렸습니다.
#model.fit(X_train, y_train, epochs=5, verbose = 1)

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)      # test 데이터를 넣었을 때의 loss, acc
print(test_acc)   # 정확도

# 모델 예측
pred = model.predict(X_test)    # 예측 데이터를 ()안에 넣으면 됩니다.

figure, axes = plt.subplots(nrows=2, ncols=2, figsize = (35, 15))
axes[0][0].set_title('Test Image')
axes[0][0].imshow(y_test_org.T)
axes[0][1].set_title('Pred Image')
axes[0][1].imshow(pred.T)
axes[1][0].set_title('Test Image')
axes[1][0].imshow(df)
df_test_img = df
if X_shape[1] % 2 == 0:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2):360-int(X_shape[1]/2)] = pred.T
else:
    df_test_img.iloc[y_test_range[0]:y_test_range[1], 0+int(X_shape[1]/2)+1:360-int(X_shape[1]/2)] = pred.T
axes[1][1].set_title('Pred Image')
axes[1][1].imshow(df_test_img)
figure.colorbar;

figure.tight_layout()
plt.show()

# %% [markdown]
# # 예측 범위가 넓어서 그런지 예측 값이 별로 좋지 않네요...
#
# 이전 예측 범위는 5 -> 현재 예측 범위가 11
#
# 파라미터들을 수정해서 모델을 고치거나, 예측 범위를 줄여야 할것 같아요 !

# %%
# 주신 line이랑 제가 따로 중심부분만 딴 부분이랑 중간 중간 몇군데씩 안맞는 부분 있어서 제가 따로 딴 line을 사용 했습니다.
df_line == [i - min(metal_line) for i in metal_line]
# Out:
#     0     1     2      3     4     5    ...   354   355   356   357   358   359
# 0  True  True  True  False  True  True  ...  True  True  True  True  True  True
#
# [1 rows x 360 columns]

# %%
# mat 저장
import scipy.io as sio
# sio.savemat('df_test_img.mat', {'values' : df_test_img.values})
